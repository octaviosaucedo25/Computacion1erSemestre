# %%
import matplotlib.pyplot as plt
import math

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

# %%
2**3
# Out:
# 8

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
2.56**6.7
# Out:
# 543.5102860150533

# %%
plt.polar([0,3.1416],[0,1],marker='o')

# %%
#EXPLORAR LOS VALORES QUE DA LA FUNCION ATAN
math.atan(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-18-901983fce5c5> in <module>
#       1 #EXPLORAR LOS VALORES QUE DA LA FUNCION ATAN
# ----> 2 math.atan(1/0)
#
# ZeroDivisionError: division by zero

# %%
a = float(input("Ingrese el valor de la parte real de z, a:" ))
b = float(input("Ingrese el valor de la parte imaginaria de z, b:" ))

z = complex(a,b)

magnitudz= math.sqrt(a**2+b**2)
#anguloz  = math.atan(b/a)

def anguloz(a,b):
    if a>0 and b==0:
        angz = 0
    if a==0 and b>0:
        angz = math.pi/2
    if a<0 and b==0:
        angz = math.pi
    if a==0 and b<0:
        angz = (3*math.pi)/2

    if a>0 and b>0:
        angz = math.atan(b/a)
    if a<0 and b>0:
        angz = math.atan(b/a) + math.pi
    if a<0 and b<0:
        angz = math.atan(b/a) + math.pi
    if a>0 and b<0:
        angz = math.atan(b/a) + 2*math.pi
    return angz
print(magnitudz)
angz = anguloz(a,b)
print(angz)

plt.polar([0,angz],[0,magnitudz],marker='o')
# Out:
# Ingrese el valor de la parte real de z, a: -1
# Ingrese el valor de la parte imaginaria de z, b: 1
# 1.4142135623730951
# 2.356194490192345

# %%
math.atan(1/math.sqrt(3))
# Out:
# 0.5235987755982989

# %%
#CÓMO GRAFICAR SEGMENTOS
plt.polar([math.pi/4,math.pi/2],[5,5],marker='o')

# %%
import matplotlib.pyplot as plt
import math


print("Bienvenido. Este programa dibuja un círculo de radio r utilizando como entrada un número complejo z escrito ya sea en su forma binómica o en su forma polar.")

a = float(input("Ingrese el valor de la parte real de z, a:" ))
b = float(input("Ingrese el valor de la parte imaginaria de z, b:" ))

z = complex(a,b)

magnitudz= math.sqrt(a**2+b**2)
#anguloz  = math.atan(b/a)
angz = anguloz(a,b)

#print(z)
#print(magnitudz)
#print(anguloz)

plt.polar([0,angz],[0,magnitudz],marker='o')
plt.show()

n = int(input("Ingrese el índice de la raíz n:" ))

for i in range(2,n+1): 
    for k in range(0,n):

        c = magnitudz**(1/i)*math.cos((angz+2*math.pi*k)/n)
        d = magnitudz**(1/i)*math.sin((angz+2*math.pi*k)/n)
        #print(c)
        #print(d)
        raiz = complex(c,d)

        magnitudraiz = math.sqrt(c**2+d**2)
        angraiz = anguloz(c,d)

        plt.polar([0,angraiz],[0,magnitudraiz],marker='o',color='navy')

        #print(raiz)
        #print(magnitudraiz)
        #print(angraiz)

# %%
a = range(0,5)
print(list(a))
# Out:
# [0, 1, 2, 3, 4]

# %%
print("Bienvenido. Este programa dibuja un círculo de radio r utilizando como entrada un número complejo z escrito ya sea en su forma binómica o en su forma polar.")

a = float(input("Ingrese el valor de la parte real de z, a:" ))
b = float(input("Ingrese el valor de la parte imaginaria de z, b:" ))

z = complex(a,b)

magnitudz= math.sqrt(a**2+b**2)
#anguloz  = math.atan(b/a)
angz = anguloz(a,b)

#print(z)
#print(magnitudz)
#print(anguloz)

plt.polar([0,angz],[0,magnitudz],marker='o')
plt.show()

n = int(input("Ingrese el índice de la raíz n:" ))

for i in range(2,n+1): 
    for k in range(0,n):

        c = magnitudz**(1/i)*math.cos((angz+2*math.pi*k)/n)
        d = magnitudz**(1/i)*math.sin((angz+2*math.pi*k)/n)
        #print(c)
        #print(d)
        raiz = complex(c,d)

        magnitudraiz = math.sqrt(c**2+d**2)
        angraiz = anguloz(c,d)

        plt.polar([0,angraiz],[0,magnitudraiz],marker='o',color='navy')
        
        lado = math.sqrt(2)*magnitudraiz*math.sqrt(1-math.cos(angraiz))
        for j in range(0,n+1):
        plt.polar([angraiz,math.pi/2],[magnitudraiz,lado],marker='o',color='navy')

        #print(raiz)
        #print(magnitudraiz)
        #print(angraiz)
# Out:
# [range(0, 2)]

# %%
# EL BUEEEENOOOOOO
import matplotlib.pyplot as plt
import math

print("Bienvenido. Este programa dibuja un círculo de radio r utilizando como entrada un número complejo z escrito ya sea en su forma binómica o en su forma polar.")

a = float(input("Ingrese el valor de la parte real de z, a:" ))
b = float(input("Ingrese el valor de la parte imaginaria de z, b:" ))

z = complex(a,b)

magnitudz= math.sqrt(a**2+b**2)
#anguloz  = math.atan(b/a)
angz = anguloz(a,b)

#print(z)
#print(magnitudz)
#print(anguloz)

plt.polar([0,angz],[0,magnitudz],marker='o')
plt.show()

n = int(input("Ingrese el índice de la raíz n:" ))

for k in range(0,n):
    c = magnitudz**(1/n)*math.cos((angz+2*math.pi*k)/n)
    d = magnitudz**(1/n)*math.sin((angz+2*math.pi*k)/n)
        #print(c)
        #print(d)
    raiz = complex(c,d)

    magnitudraiz = math.sqrt(c**2+d**2)
    angraiz = anguloz(c,d)

    #lado = math.sqrt(2)*magnitudraiz*math.sqrt(1-math.cos(2*math.pi/n))  
    lado = magnitudraiz*math.sin((2*math.pi)/n)
    plt.polar([0,angraiz],[0,magnitudraiz],marker='o',color='navy')
    
    #for i in range(1,n+1):
    plt.polar([angraiz,(2*math.pi*(k+1))/n],[magnitudraiz,lado],marker='o',color='navy')
    
#c = magnitudz**(1/n)*math.cos(angz/n)
#d = magnitudz**(1/n)*math.sin(angz/n)
#k = 1
  #  lado = math.sqrt(2)*magnitudraiz*math.sqrt(1-math.cos(angraiz))
    #for i in range(0,n+1):
   # plt.polar([angraiz,angraiz/n],[magnitudraiz,lado],marker='o',color='navy')

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
def raicesz(a,b,n):                                                       # La función depende de a, b y n.
    moduloz = m.sqrt(a**2+b**2)                                           # Módulo del complejo z.
    print("El módulo de z, es:",moduloz,"unidades.")                      # Se muestra el valor del módulo.
    argz = anguloz(a,b)                                                   # Ángulo del complejo definido con la función previa "anguloz".
    print("El argumento o ángulo de z es:",argz,"radianes.")              # Se muestra el argumento de z.
    z = complex(a,b)                                   
    print("El número complejo z es:",z)                     
    print("Gráfica del número complejo z")
    plt.polar([0,argz],[0,moduloz],marker='o',color='navy')               # Gráfica de z en el plano polar.
    plt.title("Número complejo $z=a+bi$")                                 # Título de la gráfica.
    plt.show() 
    # Se muestra primero esta gráfica.
    partereal = []
    parteimaginaria = []
    for k in range(0,n):                                                  # Realmente es el rango (0,n-1).
        c = moduloz**(1/n)*m.cos((argz+2*m.pi*k)/n)                       # Parte real de las raíces.
        d = moduloz**(1/n)*m.sin((argz+2*m.pi*k)/n)
        partereal.append(c)
        parteimaginaria.append(d)
        # Parte imaginaria de las raíces.
        raiz = complex(c,d)
        print("La raíz",k,"es:",raiz)
        moduloraiz = m.sqrt(c**2+d**2)                                    # Módulo de las raíces.
        argraiz = anguloz(c,d)                                            # Argumento de las raíces.
        plt.polar([0,argraiz],[0,moduloraiz],marker='o',color='navy')     # Gráfica de cada una de las n raíces.
        plt.title("Raíces n-ésimas de $z$")

# %% [markdown]
# ## Con segmentos

# %%
# import matplotlib.pyplot as plt
import math as m

def anguloz(x,y):
    # Definimos los valores del ángulo para un complejo sobre cada uno de los 4 semiejes del plano cartesiano:
    if x>0 and y==0:          # Semieje x positivo.
        angz = 0
    if x==0 and y>0:          # Semieje y positivo.
        angz = m.pi/2
    if x<0 and y==0:          # Semieje x negativo.
        angz = m.pi
    if x==0 and y<0:          # Semieje y negativo.
        angz = (3*m.pi)/2
   
    # Ahora definimos el ángulo para cada uno de los cuadrantes:

     # Cuadrante I: tangente>0, no hay problema (la función "atan" sirve).
    if x>0 and y>0:                       
        angz = m.atan(y/x)
    # Cuadrante II: tangente<0, habrá que sumar 180° al ángulo devuelto por "atan".    
    if x<0 and y>0:                        
        angz = m.atan(y/x) + m.pi
    # Cuadrante III: tangente>0, habrá que sumar 180° al ángulo devuelto por "atan".    
    if x<0 and y<0:                       
        angz = m.atan(y/x) + m.pi
    # Cuadrante IV: tangente<0, habrá que sumar 360° al ángulo devuelto por "atan".    
    if x>0 and y<0:                       
        angz = m.atan(y/x) + 2*m.pi
    return angz    # Regresa el valor del ángulo ajustado a su cuadrante correspondiente según "x" y "y".

print("Bienvenido. Este programa dibuja un círculo de radio r=|z|^{1/n} utilizando como entrada un número complejo z escrito en su forma binómica. Además, veremos una figura tipo regilete dependiendo del valor de n. ")

comprobar = True
while comprobar==True:
    print("1. Iniciar programa")
    print("2. Finalizar programa")
    comprobar = input("Seleccione una opción: ")
    if comprobar=='1':
        #comprobar=True

        a = float(input("Ingrese el valor de la parte real de z, a:" ))
        b = float(input("Ingrese el valor de la parte imaginaria de z, b:" ))

        z = complex(a,b)

        magnitudz= m.sqrt(a**2+b**2)
        #anguloz  = math.atan(b/a)
        angz = anguloz(a,b)

        z = complex(a,b)
        print("El número complejo z es:",z)
        print("La magnitud de z es:",magnitudz)
        print("El ángulo de z es:",anguloz,"radianes")

        plt.polar([0,angz],[0,magnitudz],marker='o')
        plt.show()
        
        #comprobar=False

        n = int(input("Ingrese el índice de la raíz n:" ))
        #comprobar=True
        
        for k in range(0,n):
            c = magnitudz**(1/n)*m.cos((angz+2*m.pi*k)/n)
            d = magnitudz**(1/n)*m.sin((angz+2*m.pi*k)/n)
                #print(c)
                #print(d)
            raiz = complex(c,d)

            magnitudraiz = m.sqrt(c**2+d**2)
            angraiz = anguloz(c,d)

            #lado = math.sqrt(2)*magnitudraiz*math.sqrt(1-math.cos(2*math.pi/n))  
            lado = magnitudraiz*m.sin((2*m.pi)/n)
            plt.polar([0,angraiz],[0,magnitudraiz],marker='o',color='navy')

            #for i in range(1,n+1):
            plt.polar([angraiz,(2*m.pi*(k+1))/n],[magnitudraiz,lado],marker='o',color='navy')

        #c = magnitudz**(1/n)*math.cos(angz/n)
        #d = magnitudz**(1/n)*math.sin(angz/n)
        #k = 1
          #  lado = math.sqrt(2)*magnitudraiz*math.sqrt(1-math.cos(angraiz))
            #for i in range(0,n+1):
           # plt.polar([angraiz,angraiz/n],[magnitudraiz,lado],marker='o',color='navy')
    else:
        print("Gracias por reproducir este programa.")
        break
# Out:
# Bienvenido. Este programa dibuja un círculo de radio r=|z| utilizando como entrada un número complejo z escrito en su forma binómica.
# 1. Iniciar programa
# 2. Finalizar programa
# Seleccione una opción:  1
# Ingrese el valor de la parte real de z, a: 0
# Ingrese el valor de la parte imaginaria de z, b: 1
# El número complejo z es: 1j
# La magnitud de z es: 1.0
# El ángulo de z es: <function anguloz at 0x0000025F0AA98820> radianes
# Ingrese el índice de la raíz n: 500
